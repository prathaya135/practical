# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Mall_Customers.csv')
df= df[{'Annual Income (k$)','Spending Score (1-100)'}]
# Out:
# C:\Users\bprat\AppData\Local\Temp\ipykernel_2152\1887465099.py:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df= df[{'Annual Income (k$)','Spending Score (1-100)'}]

# %%
plt.title('unclustered data')
plt.xlabel('Annual income')
plt.ylabel('Spending score ')
plt.scatter(x=df['Annual Income (k$)'],y=df['Spending Score (1-100)'])
plt.show()

# %%
from sklearn.cluster import KMeans,AgglomerativeClustering

# %%
sse=[]
for k in range(1,10):
    km = KMeans(n_clusters=k)
    km.fit_predict(df)
    sse.append(km.inertia_)

sse
# Out:
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [269981.28,
#  181363.595959596,
#  106348.37306211118,
#  73679.78903948836,
#  44448.45544793371,
#  37265.86520484346,
#  30273.394312070042,
#  25050.832307547527,
#  21862.09267218289]

# %%
# sse = pd.DataFrame(sse)
plt.title('elbow')
plt.xlabel('no clusters')
plt.ylabel('sse')
plt.plot(range(1,10),sse)
plt.show()

# %%
from sklearn.metrics import silhouette_score
silh=[]
for k in range(2,10):
    km = KMeans(n_clusters=k)
    label=km.fit_predict(df)
    score = silhouette_score(df,label)
    silh.append(score)

silh
# Out:
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bprat\OneDrive\Desktop\python\python\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [0.28622678604047447,
#  0.46761358158775435,
#  0.4931963109249047,
#  0.553931997444648,
#  0.5376203956398481,
#  0.5288104473798049,
#  0.45544193969058644,
#  0.4607224274992025]

# %%
plt.title('elbow')
plt.xlabel('no clusters')
plt.ylabel('sse')
plt.bar(range(2,10),silh)
plt.show()

# %%
km = KMeans(n_clusters=5)
km.fit_predict(df)

# %%
plt.title('unclustered data')
plt.xlabel('Annual income')
plt.ylabel('Spending score ')
plt.scatter(x=df['Annual Income (k$)'],y=df['Spending Score (1-100)'],c=label)
plt.show()
